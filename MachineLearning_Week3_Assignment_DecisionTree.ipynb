# %%
import pandas as pd

# %%
dataset=pd.read_csv('50_Startups.csv')

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'Profit',
#        'State_Florida', 'State_New York'],
#       dtype='object')

# %%
independent=dataset[['R&D Spend', 'Administration', 'Marketing Spend','State_Florida', 'State_New York']]

# %%
dependent=dataset[['Profit']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-1ccf68fee1da> in <module>
# ----> 1 from sklearn.model_selection import train_test_split
#       2 X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/__init__.py in <module>
#      80     from . import _distributor_init  # noqa: F401
#      81     from . import __check_build  # noqa: F401
# ---> 82     from .base import clone
#      83     from .utils._show_versions import show_versions
#      84
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in <module>
#      18
#      19 from . import __version__
# ---> 20 from .utils import _IS_32BIT
#      21
#      22 _DEFAULT_TAGS = {
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/__init__.py in <module>
#      18 import warnings
#      19 import numpy as np
# ---> 20 from scipy.sparse import issparse
#      21
#      22 from .murmurhash import murmurhash3_32
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/sparse/__init__.py in <module>
#     227 import warnings as _warnings
#     228
# --> 229 from .base import *
#     230 from .csr import *
#     231 from .csc import *
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/sparse/base.py in <module>
#       6 from scipy._lib.six import xrange
#       7 from scipy._lib._numpy_compat import broadcast_to
# ----> 8 from .sputils import (isdense, isscalarlike, isintlike,
#       9                       get_sum_dtype, validateaxis, check_reshape_kwargs,
#      10                       check_shape, asmatrix)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/sparse/sputils.py in <module>
#      15                     'uintc', 'longlong', 'ulonglong', 'single', 'double',
#      16                     'longdouble', 'csingle', 'cdouble', 'clongdouble']
# ---> 17 supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
#      18
#      19 _upcast_memo = {}
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/sparse/sputils.py in <listcomp>(.0)
#      15                     'uintc', 'longlong', 'ulonglong', 'single', 'double',
#      16                     'longdouble', 'csingle', 'cdouble', 'clongdouble']
# ---> 17 supported_dtypes = [np.typeDict[x] for x in supported_dtypes]
#      18
#      19 _upcast_memo = {}
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/__init__.py in __getattr__(attr)
#     318             return Tester
#     319
# --> 320         raise AttributeError("module {!r} has no attribute "
#     321                              "{!r}".format(__name__, attr))
#     322
#
# AttributeError: module 'numpy' has no attribute 'typeDict'

# %%
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor()
regressor=regressor.fit(X_train,y_train)

# %%
import matplotlib.pyplot as plt


from sklearn import tree
tree.plot_tree(regressor)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-4cabd73924d4> in <module>
# ----> 1 import matplotlib.pyplot as plt
#       2
#       3
#       4 from sklearn import tree
#       5 tree.plot_tree(regressor)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.7.5-cp38-cp38-macosx_10_12_x86_64.whl (7.4 MB)
#      |████████████████████████████████| 7.4 MB 343 kB/s eta 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.1-cp38-cp38-macosx_10_9_x86_64.whl (247 kB)
#      |████████████████████████████████| 247 kB 215 kB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Max/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (2.8.1)
# Collecting numpy<2,>=1.20
#   Downloading numpy-1.24.4-cp38-cp38-macosx_10_9_x86_64.whl (19.8 MB)
#      |████████████████████████████████| 19.8 MB 27 kB/s eta 0:00:010
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/importlib-resources/
# Collecting importlib-resources>=3.2.0
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/e1/6a/4604f9ae2fa62ef47b9de2fa5ad599589d28c9fd1d335f32759813dfa91e/importlib_resources-6.4.5-py3-none-any.whl
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fa8e77ea820>, 'Connection to files.pythonhosted.org timed out. (connect timeout=15)')': /packages/e1/6a/4604f9ae2fa62ef47b9de2fa5ad599589d28c9fd1d335f32759813dfa91e/importlib_resources-6.4.5-py3-none-any.whl
#   WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fa8e77ea670>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /packages/e1/6a/4604f9ae2fa62ef47b9de2fa5ad599589d28c9fd1d335f32759813dfa91e/importlib_resources-6.4.5-py3-none-any.whl
#   WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fa8e77ead60>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')': /packages/e1/6a/4604f9ae2fa62ef47b9de2fa5ad599589d28c9fd1d335f32759813dfa91e/importlib_resources-6.4.5-py3-none-any.whl
#   Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/Max/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (20.9)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.7-cp38-cp38-macosx_10_9_x86_64.whl (65 kB)
#      |████████████████████████████████| 65 kB 281 kB/s eta 0:00:01
# Requirement already satisfied: pillow>=6.2.0 in /Users/Max/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (8.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/Max/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.57.0-cp38-cp38-macosx_10_9_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 314 kB/s eta 0:00:01     |██████████████████████████▌     | 1.9 MB 306 kB/s eta 0:00:02
# Requirement already satisfied: zipp>=3.1.0 in /Users/Max/opt/anaconda3/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.4.1)
# Requirement already satisfied: six>=1.5 in /Users/Max/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Installing collected packages: numpy, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.1
#     Uninstalling numpy-1.19.1:
#       Successfully uninstalled numpy-1.19.1
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.57.0 importlib-resources-6.4.5 kiwisolver-1.4.7 matplotlib-3.7.5 numpy-1.24.4
