# %%
import pickle
load_model=pickle.load(open("Finalised_model_Multiple_linear.sav",'rb'))
result=load_model.predict([[2435,342,3236,0,0]])

# %%
#Final predicted o/p
result
# Out:
# array([[49170.45434214]])
